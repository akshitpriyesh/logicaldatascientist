# %%
import torch

if torch.cuda.is_available():
    print("GPU is available")
    gpu_name = torch.cuda.get_device_name(0)  # 0 is the index for the first GPU
    print(f"GPU Name: {gpu_name}")
else:
    print("GPU is not available")

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolo11n.pt") 
# Set a custom learning rate
learning_rate = 0.001  # Example value; adjust as needed
#results = model.train(data="coco8.yaml", imgsz=640, epochs=10, batch=2, lr0=learning_rate, lrf=0.01, warmup_epochs=3.0)
results = model.train(data="custom_bdd.yaml", epochs=50, imgsz=640, batch=2)
# Out:
# Ultralytics 8.3.18 🚀 Python-3.10.15 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 3899MiB)
# ...

# %%
model = YOLO("runs/detect/train16/weights/last.pt")

# %%
results = model.predict("cc4d418c-6070d7f8.jpg", save=True, show=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results = model.predict("cc4d418c-6070d7f8.jpg", save=True, show=True)
#
# NameError: name 'model' is not defined

# %%
#results = model.predict("akshit_road.mp4", save=True, show=True)
